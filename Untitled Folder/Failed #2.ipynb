# %%
import numpy as np

# %%
from keras.models import load_model

# %%
new_model = load_model('93% Accuracy.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_78 (Dense)             (None, 32)                192
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 2)                 66
# ...
# Total params: 1,314
# Trainable params: 1,314
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.get_weights()
# Out:
# [array([[ 1.76451460e-01,  1.76104844e-01,  1.00599185e-01,
#          -7.75649920e-02, -2.01990344e-02, -2.59096146e-01,
#          -5.35606503e-01, -2.95239270e-01,  2.38999333e-02,
#          -1.36445552e-01, -4.59654927e-02,  3.04628387e-02,
#          -3.95636529e-01, -3.76688182e-01, -5.86684905e-02,
#          -9.61595252e-02, -1.58723429e-01, -1.52683765e-01,
#          -3.84828134e-04, -1.88088566e-01, -5.04178889e-02,
#          -7.68710673e-02, -2.12523505e-01, -2.10475817e-01,
#           5.35055175e-02,  1.93059146e-01,  2.73067743e-01,
#           5.15017331e-01,  3.47203016e-02, -7.78761208e-02,
#           5.41051328e-02, -1.65910050e-02],
#         [-3.03914100e-01,  1.72879696e-01, -1.00908309e-01,
#           1.43026263e-01,  5.76763868e-01, -2.56154835e-02,
#           9.74261668e-03,  5.52839935e-02, -3.37498784e-01,
#          -1.75460786e-01,  2.90527582e-01, -3.36041510e-01,
#          -3.88170719e-01,  3.52548301e-01, -2.24496424e-01,
# ...

# %%
new_model.optimizer

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d77a5b3a74ca> in <module>
# ----> 1 predictions = new_model.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
# Out:
# [[1.00000e+00 3.82861e-05]]
